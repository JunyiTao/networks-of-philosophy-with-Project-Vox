# %%
import json
import pandas as pd
import os
# uuid
from django.utils.crypto import get_random_string

# %% [markdown]
# convert
# 1. json -- index
#     corres (uuid) - subtopic
#     subtopic - topic
#
#     node
#     {
#     "labels": ["correspondence"],
#     "id": uuid
#     },
#     {
#     "labels": ["subtopic"],
#     "id": get_random_string(8)
#     },
#     {
#     "labels": ["topic"],
#     "id": get_random_string(8)
#     },
#
#     link
#     {
#     "type": "topic_subtopic",
#     "id": 147,
#     "source": 21,
#     "target": 344,
#     "value": 1
#     },
#     {
#     "type": "corres_subtopic",
#     "id": 147,
#     "source": 21,
#     "target": 344,
#     "value": 1
#     },
#
#
# 2. csv -- people
#
# config link--match property

# %%
#********************************** index

with open(os.path.expanduser('data_prep/r_e_corres_theme_group.json')) as f:
    corres_list = json.load(f)

node_list, link_list = [], []
node_corr_list, node_top_list, node_subtop_list = [], [], []
link_corr_top_list, link_corr_subtop_list, link_topic_subtop_list = [], [], []

# print
for corr in corres_list:
    node_corr_dict={
        "labels": ["correspondence"],
        "id": corr['unique_id'], # can hardly be replaced by the name
        "properties": {
            "name": corr['from']+" TO "+corr['to']+" "+str(corr['date']).replace("'", '').replace("]", "").replace("[", ""),
            "value": 0,
            "count_mentioned": 1,

            "from": corr['from'],
            "to": corr['to'],
            "date": corr['date'],
            "grouped_themes_count": corr["label"]["index_shapiro"]["grouped_themes_count"],
            "grouped_themes": str(corr["label"]["index_shapiro"]["grouped_themes"]).replace("'", '"').replace("], ", "<br>").replace("]", "").replace("[", "").replace("{", "").replace("}", ""),
            "grouped_themes_count_detailed": str(corr["label"]["index_shapiro"]["grouped_themes_count_detailed"]).replace(", '", '<br/>').replace("': ", ': ').replace("}", '').replace("{'", ''),

            "location": corr["location"],
            "translated_text": corr["content"]["text"]["translated_text"],
            }
        }
    node_corr_list.append(node_corr_dict)

    for top in corr["label"]["index_shapiro"]["grouped_themes"].keys():
        # increase value of node-correspondence
        node_corr_dict["properties"]['value'] += 1

        # record information
        node_top_dict={
            "labels": ["topic"],
            "id": get_random_string(8),
            "properties": {
                "name": top,
                "count_subtopic": 0,
                "count_mentioned": 1,
                "subtopics": corr["label"]["index_shapiro"]["grouped_themes"][top]
            }
            }
        link_corr_top_dict={
            "type": "corres_topic",
            "id": get_random_string(8),
            "source": node_corr_dict["properties"]['name'],
            "target": node_top_dict["properties"]['name'],
            "properties": {
                "value": 1
            }
            }
        node_top_list.append(node_top_dict)
        link_corr_top_list.append(link_corr_top_dict)

        for subtop in corr["label"]["index_shapiro"]["grouped_themes"][top]:

            # record information
            node_subtop_dict={
                "labels": ["subtopic"],
                "id": get_random_string(8),
                "properties": {
                    "name": subtop,
                    "value": 0,
                    "count_mentioned": 1,
                    "parent_topic": top
                }
                }
            link_corr_subtop_dict={
                "type": "corres_subtopic",
                "id": get_random_string(8),
                "source": node_corr_dict["properties"]['name'],
                "target": node_subtop_dict["properties"]['name'],
                "properties": {
                    "value": 1
                }
                }
            link_topic_subtop_dict={
                "type": "topic_subtopic",
                "id": get_random_string(8),
                "source": node_top_dict["properties"]['name'],
                "target": node_subtop_dict["properties"]['name'],
                "properties": {
                    "value": 1
                }
                }
            node_subtop_list.append(node_subtop_dict)
            link_corr_subtop_list.append(link_corr_subtop_dict)
            link_topic_subtop_list.append(link_topic_subtop_dict)

# remove the duplicates from all lists of dicts
def remove_duplicates_node(list_of_dicts):
    # dulicated if node["properties"]['name'] are the same
    unique_list, unique_name_list = [], []
    for node in list_of_dicts:
        if node["properties"]['name'] not in unique_name_list:
            unique_name_list.append(node["properties"]['name'])
            unique_list.append(node)
        # increase count_mentioned if duplicated
        else:
            for unique_node in unique_list:
                if node["properties"]['name'] == unique_node["properties"]['name']:
                    # increase count_mentioned
                    unique_node["properties"]['count_mentioned'] += 1
                    # append to the list of subs if ["properties"]["subtopic"] exists
                    if "subtopics" in node["properties"].keys():
                        unique_node["properties"]["subtopics"] += node["properties"]["subtopics"]
    
    # if ["properties"]["subtopic"] exists, remove duplicates and change the format
    # str(["properties"]["subtopic"]).replace("', '","<br/>").replace("'", "").replace("]", "").replace("[", "")
    for node in unique_list:
        if "subtopics" in node["properties"].keys():
            node["properties"]["subtopics"] = list(set(node["properties"]["subtopics"]))
            # set count_subtopic
            node["properties"]["count_subtopic"] = len(node["properties"]["subtopics"])
            # change and clean the format
            node["properties"]["subtopics"] = str(node["properties"]["subtopics"]).replace("', '","<br/>").replace("'", "").replace("]", "").replace("[", "")
    return unique_list

node_corr_list = remove_duplicates_node(node_corr_list)
node_top_list = remove_duplicates_node(node_top_list)
node_subtop_list = remove_duplicates_node(node_subtop_list)

def remove_duplicates_link(list_of_dicts):
    # dulicated if source and target are the same
    # add up value if duplicated
    unique_list, unique_name_list = [], []
    for link in list_of_dicts:
        if link['source']+" "+link['target'] not in unique_name_list:
            unique_name_list.append(link['source']+" "+link['target'])
            unique_list.append(link)
        else:
            for unique_link in unique_list:
                if link['source'] == unique_link['source'] and link['target'] == unique_link['target']:
                    unique_link["properties"]['value'] += 1
        
    # replace names of source and target with ids
    node_all_list = node_corr_list + node_top_list + node_subtop_list
    for link in unique_list:
        for node in node_all_list:
            if link['source'] == node["properties"]['name']:
                link['source'] = node['id']
                source_name = node["properties"]['name']
            if link['target'] == node["properties"]['name']:
                link['target'] = node['id']
                target_name = node["properties"]['name']
        link["properties"]['name'] = source_name + " -> " + target_name

    return unique_list

link_corr_top_list = remove_duplicates_link(link_corr_top_list)
link_corr_subtop_list = remove_duplicates_link(link_corr_subtop_list)
link_topic_subtop_list = remove_duplicates_link(link_topic_subtop_list)


# how to deal with self to self--corres directly mention the topic not the subtopic
# subtopic include the topic name

# %%
# combine
# topic - (subtopic) - corres
node_list = node_corr_list + node_top_list
link_list = link_corr_top_list
node_link_dict = {"nodes": node_list, "links": link_list}
# josn dump
with open(os.path.expanduser('js/07-16-2023/graph_corr_topic.js'), 'w') as f:
    # write to json file "var graph_corr_topic ="
    f.write("var graph_corr_topic = ")
    json.dump(node_link_dict, f, indent=4)

# %%
#********************************** graph_phil_pv
# node: people, connections
# link: the connection, with types, directed?
# people - connection - people

# read json file /Users/junyitao/Documentation/research/SW/shapiro_correspondence/correspondence_index/data_prep/people.json
with open(os.path.expanduser('data_prep/people.json')) as f:
    people_list = json.load(f)


node_list, link_list = [], []
node_people_list, node_conn_list = [], []
link_people_conn_list = []

for people in people_list:
    node_people_dict = { # no depulicates
        "labels": ["people"],
        "id": get_random_string(8),
        "properties":{
            "name": people['name'],
            "sameAs": people['sameAs'],
            "roles": people['roles'],
            "connections": people['connections'],
            "value": 0
        }
    }
    node_people_list.append(node_people_dict)

    for conn in people['connections']:
        # increase value of node-people
        node_people_dict["properties"]['value'] += 1

        # record information
        node_conn_dict = {
            "labels": ["connection"],
            "type": conn["type"],
            "id": conn["unique_id"],
            "properties":{
                "name": conn["from"]+" TO "+conn["to"]+" "+str(conn["date"]).replace("[", '').replace("]", ''),
                "value": 0,
                "people": people['name'],
                "source": conn["source"],
                "from": conn["from"],
                "to": conn["to"],
                "date": conn["date"],
                "location": conn["location"],
                "translated_text": conn["content"]["text"]["translated_text"]
            }
        }
        link_people_conn_dict = {
            "type": "people_connection",
            "id": get_random_string(8),
            # here we use id of people and connections
            # they are supposed to be depulicated twice
            "source": node_people_dict["id"],
            "target": node_conn_dict["id"],
            "properties": {
                "value": 0
            }
        }
        node_conn_list.append(node_conn_dict)
        link_people_conn_list.append(link_people_conn_dict)

# remove duplicates of node_conn_list, with id
def remove_duplicates_node_conn(list_of_dicts):
    # dulicated if node["properties"]['name'] are the same
    unique_list, unique_name_list = [], []
    for node in list_of_dicts:
        if node["id"] not in unique_name_list:
            unique_name_list.append(node["id"])
            unique_list.append(node)
    
    return unique_list

node_conn_list = remove_duplicates_node_conn(node_conn_list)

node_conn_dict
# Out:
# {'labels': ['connection'],
#  'type': 'correspondence',
#  'id': '846e3c2b-aef2-4cc3-8dd3-f15bca338e17',
#  'properties': {'name': "Samson Johnson TO Sorbiere, Samuel '08/27/1644'",
#   'value': 0,
#   'people': 'Samson Johnson',
#   'source': {'projectvox_team': ['Alexandrescu 17'],
#    'electronic_enlightenment': ''},
#   'from': 'Samson Johnson',
#   'to': 'Sorbiere, Samuel',
#   'date': ['08/27/1644'],
#   'location': [],
#   'translated_text': ''}}

# %%
# combine
# people - connection - people
node_list = node_people_list + node_conn_list
link_list = link_people_conn_list
node_link_dict = {"nodes": node_list, "links": link_list}
# josn dump
with open(os.path.expanduser('js/07-16-2023/graph_phil_pv.js'), 'w') as f:
    # write to json file "var graph_phil_pv="
    f.write("var graph_phil_pv = ")
    json.dump(node_link_dict, f, indent=4)

# %% [markdown]
# ## Exprimental part (unused)

# %%
#********************************** graph_phil_other

# read from csv

# medium nodes are prefered to links (with label) here because straight lines overlap with each other

node_list, link_list = [], []
node_people_list, node_conn_list = [], []
link_people_conn_list = []

for people in people_list:
    node_people_dict = { # no depulicates
        "labels": ["people"],
        "id": get_random_string(8),
        "properties":{
            "name": people['name'],
            "sameAs": people['sameAs'],
            "roles": people['roles'],
            "connections": people['connections'],
            "value": 0
        }
    }
    node_people_list.append(node_people_dict)

    for conn in people['connections']:
        # increase value of node-people
        node_people_dict["properties"]['value'] += 1

        # record information
        node_conn_dict = {
            "labels": ["connection"],
            "type": conn["type"],
            "id": conn["unique_id"],
            "properties":{
                "name": conn["from"]+" TO "+conn["to"]+" "+str(conn["date"]).replace("[", '').replace("]", ''),
                "value": 0,
                "people": people['name'],
                "source": conn["source"],
                "from": conn["from"],
                "to": conn["to"],
                "date": conn["date"],
                "location": conn["location"],
                "translated_text": conn["content"]["text"]["translated_text"]
            }
        }
        link_people_conn_dict = {
            "type": "people_connection",
            "id": get_random_string(8),
            # here we use id of people and connections
            # they are supposed to be depulicated twice
            "source": node_people_dict["id"],
            "target": node_conn_dict["id"],
            "properties": {
                "value": 0
            }
        }
        node_conn_list.append(node_conn_dict)
        link_people_conn_list.append(link_people_conn_dict)

# remove duplicates of node_conn_list, with id
def remove_duplicates_node_conn(list_of_dicts):
    # dulicated if node["properties"]['name'] are the same
    unique_list, unique_name_list = [], []
    for node in list_of_dicts:
        if node["id"] not in unique_name_list:
            unique_name_list.append(node["id"])
            unique_list.append(node)
    
    return unique_list

node_conn_list = remove_duplicates_node_conn(node_conn_list)

# %%
graph_phil_other

# %%
link_corr_top_list
# Out:
# [{'type': 'corres_topic',
#   'id': '30vJQbcR',
#   'source': '4beed4b9-b5ad-4d85-af2e-6fa2dcfbed7b',
#   'target': 'FSHmfGTa',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/06/1643'] -> voluntary action"},
#  {'type': 'corres_topic',
#   'id': 'TpXCAmIF',
#   'source': '4beed4b9-b5ad-4d85-af2e-6fa2dcfbed7b',
#   'target': 'w1oqbthx',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/06/1643'] -> souls"},
#  {'type': 'corres_topic',
#   'id': 'bLxCgMg0',
#   'source': '4beed4b9-b5ad-4d85-af2e-6fa2dcfbed7b',
#   'target': 'jpZRDCpS',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/06/1643'] -> action(s), human"},
#  {'type': 'corres_topic',
#   'id': 'JW05O55o',
#   'source': '4beed4b9-b5ad-4d85-af2e-6fa2dcfbed7b',
#   'target': 'wemchvia',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/06/1643'] -> substance(s)"},
#  {'type': 'corres_topic',
#   'id': 'ik1sUbPn',
#   'source': '4beed4b9-b5ad-4d85-af2e-6fa2dcfbed7b',
#   'target': '6gGF6bOV',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/06/1643'] -> power"},
#  {'type': 'corres_topic',
#   'id': 'PQXPFYUJ',
#   'source': '4beed4b9-b5ad-4d85-af2e-6fa2dcfbed7b',
#   'target': 'DAvnmVDy',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/06/1643'] -> motions/movement"},
#  {'type': 'corres_topic',
#   'id': 'qaBOmSVe',
#   'source': '4beed4b9-b5ad-4d85-af2e-6fa2dcfbed7b',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/06/1643'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': 'TM9YLSog',
#   'source': '4beed4b9-b5ad-4d85-af2e-6fa2dcfbed7b',
#   'target': 'C322NxE0',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/06/1643'] -> causation/causes"},
#  {'type': 'corres_topic',
#   'id': 'wcftKjes',
#   'source': '4beed4b9-b5ad-4d85-af2e-6fa2dcfbed7b',
#   'target': 'OqcyZ10a',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/06/1643'] -> animal spirits"},
#  {'type': 'corres_topic',
#   'id': '47oiJWdB',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'hUgDETng',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> body/bodies"},
#  {'type': 'corres_topic',
#   'id': 'GEE7s3K9',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'sBF3kMIZ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> imagination"},
#  {'type': 'corres_topic',
#   'id': 'nNImHXWh',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'w1oqbthx',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> souls"},
#  {'type': 'corres_topic',
#   'id': 'Y6R9rnb1',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'wemchvia',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> substance(s)"},
#  {'type': 'corres_topic',
#   'id': 'fiKQZen8',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'XcBNjXfx',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> duration as a primitive notion"},
#  {'type': 'corres_topic',
#   'id': 'vyVIC6oH',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'i0OkMtEs',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> number, as a primitive notion"},
#  {'type': 'corres_topic',
#   'id': '2zvXNQzU',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': '6gGF6bOV',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> power"},
#  {'type': 'corres_topic',
#   'id': 'SxY2JC88',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'DAvnmVDy',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> motions/movement"},
#  {'type': 'corres_topic',
#   'id': '39qd9tvj',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'ID2PQcRY',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> sensations"},
#  {'type': 'corres_topic',
#   'id': 'dNl6mbeO',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'CELHXGXP',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> primitive notions"},
#  {'type': 'corres_topic',
#   'id': 'FusYQWhD',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': 'nuK1TUzM',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'CLUR4HrV',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> extension"},
#  {'type': 'corres_topic',
#   'id': 'ietsJhTx',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'B0g0VY0k',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> will"},
#  {'type': 'corres_topic',
#   'id': 'u7MnEsd5',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'i7ZexkNl',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> body, human"},
#  {'type': 'corres_topic',
#   'id': 'bixUVr34',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'C322NxE0',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> causation/causes"},
#  {'type': 'corres_topic',
#   'id': 'Mq3Z7DIa',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'mmWWLCJf',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> understanding"},
#  {'type': 'corres_topic',
#   'id': 'lQ4y3qmv',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'duiXGdT2',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> heaviness"},
#  {'type': 'corres_topic',
#   'id': 'Qz1wjcBu',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'e1DzO4k5',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> union of mind and body"},
#  {'type': 'corres_topic',
#   'id': 'auk9nKHI',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'AB2dx415',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> knowledge"},
#  {'type': 'corres_topic',
#   'id': 'kQc6Wz6n',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'AZSZkijL',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> being, as a primitive notion"},
#  {'type': 'corres_topic',
#   'id': 't2DoZkhe',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'UIiP03iw',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> analogy/analogies"},
#  {'type': 'corres_topic',
#   'id': 'bafZWYTK',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'BKVug8TA',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> passion"},
#  {'type': 'corres_topic',
#   'id': '4nkk3CAQ',
#   'source': 'e388f0d6-7622-4de8-b7e4-24486a843000',
#   'target': 'jCJ0VuxN',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/21/1643'] -> sovereign good"},
#  {'type': 'corres_topic',
#   'id': 'Vs9P7tDC',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'hUgDETng',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> body/bodies"},
#  {'type': 'corres_topic',
#   'id': 'kBcJYhsZ',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'sBF3kMIZ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> imagination"},
#  {'type': 'corres_topic',
#   'id': 'zBujVtzr',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'w1oqbthx',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> souls"},
#  {'type': 'corres_topic',
#   'id': 'zI6MrYA8',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'wemchvia',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> substance(s)"},
#  {'type': 'corres_topic',
#   'id': '0pbhOw0i',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'FPqHL8ak',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> truths"},
#  {'type': 'corres_topic',
#   'id': 'BVATMEFo',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'tNHEasFJ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> mind"},
#  {'type': 'corres_topic',
#   'id': '01woaJFo',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'ds8MgXyJ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> matter"},
#  {'type': 'corres_topic',
#   'id': 'knTMDoZe',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': '6gGF6bOV',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> power"},
#  {'type': 'corres_topic',
#   'id': 'a4K07xSi',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'DwnKmezF',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> perfections"},
#  {'type': 'corres_topic',
#   'id': '12FFKnUE',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'DAvnmVDy',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> motions/movement"},
#  {'type': 'corres_topic',
#   'id': 'hm10AER7',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'CLUR4HrV',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> extension"},
#  {'type': 'corres_topic',
#   'id': 'JclQIFi9',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'i7ZexkNl',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> body, human"},
#  {'type': 'corres_topic',
#   'id': 'Ya7ZYV4f',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': '7tHmS9wO',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> immaterial thing"},
#  {'type': 'corres_topic',
#   'id': 'yKRLAlJr',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'UORgGulw',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> habit(s)/Habituation"},
#  {'type': 'corres_topic',
#   'id': 'YZe6yApx',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'C322NxE0',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> causation/causes"},
#  {'type': 'corres_topic',
#   'id': 'aizB7tNv',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'duiXGdT2',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> heaviness"},
#  {'type': 'corres_topic',
#   'id': 'K1Nbc3AI',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'ZUfPutXS',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> meditation"},
#  {'type': 'corres_topic',
#   'id': 'Bgjn96wL',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'UIiP03iw',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> analogy/analogies"},
#  {'type': 'corres_topic',
#   'id': 'VPw5Tsg7',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'JIjE7eXt',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> Bohemia, House of"},
#  {'type': 'corres_topic',
#   'id': 'RpsS5Zld',
#   'source': 'cef5aa9c-09cd-45fc-89de-fae88a137449',
#   'target': 'BKVug8TA',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/10/1643'] -> passion"},
#  {'type': 'corres_topic',
#   'id': 'GnHUdgyx',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'CBSCyXti',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> philosophy and philosophers"},
#  {'type': 'corres_topic',
#   'id': '9rueNvYD',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'hUgDETng',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> body/bodies"},
#  {'type': 'corres_topic',
#   'id': 'vi4TXCys',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'sBF3kMIZ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> imagination"},
#  {'type': 'corres_topic',
#   'id': 'NcFoNDPj',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'w1oqbthx',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> souls"},
#  {'type': 'corres_topic',
#   'id': 'JjuYziQg',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'vCf8ysD0',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> memory"},
#  {'type': 'corres_topic',
#   'id': '7BalioNU',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'tNHEasFJ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> mind"},
#  {'type': 'corres_topic',
#   'id': 'qzruEUrO',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'DAvnmVDy',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> motions/movement"},
#  {'type': 'corres_topic',
#   'id': '3bTd7F3B',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'BsWi5Oe2',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> metaphysics"},
#  {'type': 'corres_topic',
#   'id': 'YTUl4EUF',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'CELHXGXP',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> primitive notions"},
#  {'type': 'corres_topic',
#   'id': 'Vje6g6wn',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'CLUR4HrV',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> extension"},
#  {'type': 'corres_topic',
#   'id': 'IkoLRFnC',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': '5Va55qRg',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> God"},
#  {'type': 'corres_topic',
#   'id': 'jvJlgulX',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'i7ZexkNl',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> body, human"},
#  {'type': 'corres_topic',
#   'id': 'PcCVHzUV',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': '2Sa3i6HN',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> mathematics"},
#  {'type': 'corres_topic',
#   'id': 'lD92pBOk',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': '3nftlAUd',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> pure understanding"},
#  {'type': 'corres_topic',
#   'id': 'GHaH4izs',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'mmWWLCJf',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> understanding"},
#  {'type': 'corres_topic',
#   'id': 'XHoZX1FE',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'duiXGdT2',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> heaviness"},
#  {'type': 'corres_topic',
#   'id': 'HCiqwsXw',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'cDJFyini',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> Utrecht, University of"},
#  {'type': 'corres_topic',
#   'id': '2tMW5kOK',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'e1DzO4k5',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> union of mind and body"},
#  {'type': 'corres_topic',
#   'id': 'NDykOAH9',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'ZUfPutXS',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> meditation"},
#  {'type': 'corres_topic',
#   'id': '46Cl5p4h',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'YAJXm9LL',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'UIiP03iw',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> analogy/analogies"},
#  {'type': 'corres_topic',
#   'id': 'EbJby0Jh',
#   'source': 'a8f22e20-ce9b-42a9-b121-e5a32998e24e',
#   'target': 'BKVug8TA',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/28/1643'] -> passion"},
#  {'type': 'corres_topic',
#   'id': 'w6huSxG3',
#   'source': 'd329db9b-d4fc-48c3-b786-a65fcaa7a0ee',
#   'target': 'sBF3kMIZ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/01/1643'] -> imagination"},
#  {'type': 'corres_topic',
#   'id': 'Y97PPLvn',
#   'source': 'd329db9b-d4fc-48c3-b786-a65fcaa7a0ee',
#   'target': 'w1oqbthx',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/01/1643'] -> souls"},
#  {'type': 'corres_topic',
#   'id': 'HxkQ3Wyu',
#   'source': 'd329db9b-d4fc-48c3-b786-a65fcaa7a0ee',
#   'target': 'XsWzmi7M',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/01/1643'] -> error, rule for avoiding"},
#  {'type': 'corres_topic',
#   'id': '3Gtfvick',
#   'source': 'd329db9b-d4fc-48c3-b786-a65fcaa7a0ee',
#   'target': 'C5dm2pHj',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/01/1643'] -> health, bodily"},
#  {'type': 'corres_topic',
#   'id': 'IkAme6e5',
#   'source': 'd329db9b-d4fc-48c3-b786-a65fcaa7a0ee',
#   'target': 'DAvnmVDy',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/01/1643'] -> motions/movement"},
#  {'type': 'corres_topic',
#   'id': 'BKqi77JI',
#   'source': 'd329db9b-d4fc-48c3-b786-a65fcaa7a0ee',
#   'target': 'CLUR4HrV',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/01/1643'] -> extension"},
#  {'type': 'corres_topic',
#   'id': 'aZ9A7N6z',
#   'source': 'd329db9b-d4fc-48c3-b786-a65fcaa7a0ee',
#   'target': 'i7ZexkNl',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/01/1643'] -> body, human"},
#  {'type': 'corres_topic',
#   'id': 'JeU3bMgH',
#   'source': 'd329db9b-d4fc-48c3-b786-a65fcaa7a0ee',
#   'target': 'mmWWLCJf',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/01/1643'] -> understanding"},
#  {'type': 'corres_topic',
#   'id': 'rmsScngq',
#   'source': 'd329db9b-d4fc-48c3-b786-a65fcaa7a0ee',
#   'target': 'XDoEmZcf',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/01/1643'] -> scholastic philosophy/philosophers"},
#  {'type': 'corres_topic',
#   'id': 'wafgv7zY',
#   'source': 'c1a3b73a-2f3a-461d-b6cd-6e9c5e637211',
#   'target': 'cPUdybXS',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['11/17/1643'] -> geometry"},
#  {'type': 'corres_topic',
#   'id': '9twovtha',
#   'source': 'c1a3b73a-2f3a-461d-b6cd-6e9c5e637211',
#   'target': 'i7ZexkNl',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['11/17/1643'] -> body, human"},
#  {'type': 'corres_topic',
#   'id': '5ugGdCSa',
#   'source': '7c4f5c9b-a491-4338-b873-fdf6dbd0920f',
#   'target': 'FajNy9PJ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['11/21/1643'] -> Apollonius’s problem"},
#  {'type': 'corres_topic',
#   'id': 'oz4xQdBH',
#   'source': '7c4f5c9b-a491-4338-b873-fdf6dbd0920f',
#   'target': 'cPUdybXS',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['11/21/1643'] -> geometry"},
#  {'type': 'corres_topic',
#   'id': 'jx3YUd7b',
#   'source': '7a45b070-35ec-46ef-a2fd-afc1a6294718',
#   'target': 'FajNy9PJ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['11/29/1643'] -> Apollonius’s problem"},
#  {'type': 'corres_topic',
#   'id': 'aLuWAtkd',
#   'source': '7a45b070-35ec-46ef-a2fd-afc1a6294718',
#   'target': 'hBg4S6t7',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['11/29/1643'] -> vanity"},
#  {'type': 'corres_topic',
#   'id': 'eONumvpI',
#   'source': '7a45b070-35ec-46ef-a2fd-afc1a6294718',
#   'target': 'BsWi5Oe2',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['11/29/1643'] -> metaphysics"},
#  {'type': 'corres_topic',
#   'id': 'tPVeaJT4',
#   'source': '7a45b070-35ec-46ef-a2fd-afc1a6294718',
#   'target': 'cPUdybXS',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['11/29/1643'] -> geometry"},
#  {'type': 'corres_topic',
#   'id': '0yfGLC4d',
#   'source': '7a45b070-35ec-46ef-a2fd-afc1a6294718',
#   'target': 'TPrBhVCZ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['11/29/1643'] -> joy"},
#  {'type': 'corres_topic',
#   'id': 'C8r7mF6a',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'VZdBCuXr',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> astrologers"},
#  {'type': 'corres_topic',
#   'id': 'U7cK5wiG',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'w1oqbthx',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> souls"},
#  {'type': 'corres_topic',
#   'id': 'uG4HA7jb',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'kqcueRNl',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> expression of passions"},
#  {'type': 'corres_topic',
#   'id': 'a9Uhwrso',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'C5dm2pHj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> health, bodily"},
#  {'type': 'corres_topic',
#   'id': 'TlWtFugI',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'tNHEasFJ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> mind"},
#  {'type': 'corres_topic',
#   'id': '8gJNoGeJ',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'KaoxzxF5',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> medicine"},
#  {'type': 'corres_topic',
#   'id': 'n27FVdsF',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': '6gGF6bOV',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> power"},
#  {'type': 'corres_topic',
#   'id': 'UijYiimB',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'DAvnmVDy',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> motions/movement"},
#  {'type': 'corres_topic',
#   'id': 'qwL5f1Zl',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'BhRjF2Z2',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> spirits, animal"},
#  {'type': 'corres_topic',
#   'id': 'hsjOkQ0o',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': 'UB9bIMWs',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'OZIaiyVb',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> fear"},
#  {'type': 'corres_topic',
#   'id': 'HwWHIuGa',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'mboidqnX',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> shame"},
#  {'type': 'corres_topic',
#   'id': 'xGe0VldD',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'B0g0VY0k',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> will"},
#  {'type': 'corres_topic',
#   'id': 'VUKK1FkN',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'i7ZexkNl',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> body, human"},
#  {'type': 'corres_topic',
#   'id': 'BqsiwPQ5',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'hwWj8JcF',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> anger"},
#  {'type': 'corres_topic',
#   'id': '2WkoJQAX',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'OFET4fgN',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> laughter"},
#  {'type': 'corres_topic',
#   'id': 'tWDjzVcc',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'AL8B6l3h',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'TPrBhVCZ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> joy"},
#  {'type': 'corres_topic',
#   'id': 'LnW6OYTP',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'BKVug8TA',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> passion"},
#  {'type': 'corres_topic',
#   'id': 'YK8PT7Q2',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'BvHdtlwg',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> compassion"},
#  {'type': 'corres_topic',
#   'id': 'IefMClh1',
#   'source': 'cd1e943d-aee2-4931-a1d5-c15effbd25ec',
#   'target': 'OqcyZ10a',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['07/08/1644'] -> animal spirits"},
#  {'type': 'corres_topic',
#   'id': 'rrrSjE3N',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'hUgDETng',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> body/bodies"},
#  {'type': 'corres_topic',
#   'id': 's0Ot6GzR',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'C5dm2pHj',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> health, bodily"},
#  {'type': 'corres_topic',
#   'id': 'H46LVOSC',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'dLU3wbL1',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> conscience"},
#  {'type': 'corres_topic',
#   'id': 'vjFXJazv',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'ds8MgXyJ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> matter"},
#  {'type': 'corres_topic',
#   'id': 'CCJdP9YU',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': '9faJcP4p',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> particles, shell-shaped"},
#  {'type': 'corres_topic',
#   'id': 'sh1xXgQ5',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': '1Ci2rQWC',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> Principles of Philosophy"},
#  {'type': 'corres_topic',
#   'id': 'e39CjJN6',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'B0g0VY0k',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> will"},
#  {'type': 'corres_topic',
#   'id': 'hNYtPYLJ',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'mmWWLCJf',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> understanding"},
#  {'type': 'corres_topic',
#   'id': 'mgexSGXl',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'duiXGdT2',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> heaviness"},
#  {'type': 'corres_topic',
#   'id': 'GSy15Qha',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'DuU8Uk3j',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> magnetic attraction"},
#  {'type': 'corres_topic',
#   'id': 'iwrxGixn',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'ggkrIsIP',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> friendship"},
#  {'type': 'corres_topic',
#   'id': 'wgItpO4C',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'VgkRNstB',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> moral philosophy"},
#  {'type': 'corres_topic',
#   'id': 'ipDZ8ccL',
#   'source': '047098b5-60fc-4e61-a2a6-f8dd8134bf37',
#   'target': 'YXrgzjuv',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/01/1644'] -> good(s)"},
#  {'type': 'corres_topic',
#   'id': 'PNNepBfh',
#   'source': 'dc31b8a3-720c-4cc5-8cd8-2ad5b5c16f32',
#   'target': '0eWHZScy',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['08/??/1644'] -> subtle matter"},
#  {'type': 'corres_topic',
#   'id': '0GIXTsPT',
#   'source': 'dc31b8a3-720c-4cc5-8cd8-2ad5b5c16f32',
#   'target': 'ds8MgXyJ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['08/??/1644'] -> matter"},
#  {'type': 'corres_topic',
#   'id': 'ckyFTpix',
#   'source': 'dc31b8a3-720c-4cc5-8cd8-2ad5b5c16f32',
#   'target': '9faJcP4p',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['08/??/1644'] -> particles, shell-shaped"},
#  {'type': 'corres_topic',
#   'id': '9aVzP7TT',
#   'source': 'dc31b8a3-720c-4cc5-8cd8-2ad5b5c16f32',
#   'target': 'duiXGdT2',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['08/??/1644'] -> heaviness"},
#  {'type': 'corres_topic',
#   'id': 'BncgjIW0',
#   'source': 'dc31b8a3-720c-4cc5-8cd8-2ad5b5c16f32',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['08/??/1644'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'HBpkQiNf',
#   'source': 'dc31b8a3-720c-4cc5-8cd8-2ad5b5c16f32',
#   'target': 'DuU8Uk3j',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['08/??/1644'] -> magnetic attraction"},
#  {'type': 'corres_topic',
#   'id': 'YJYmXSY2',
#   'source': 'dc31b8a3-720c-4cc5-8cd8-2ad5b5c16f32',
#   'target': 'VgkRNstB',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['08/??/1644'] -> moral philosophy"},
#  {'type': 'corres_topic',
#   'id': 'I6Ughea7',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'CBSCyXti',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> philosophy and philosophers"},
#  {'type': 'corres_topic',
#   'id': '4pqUViYB',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'BNUFPxT8',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> pain"},
#  {'type': 'corres_topic',
#   'id': 'y7Ezc3V8',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'w1oqbthx',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> souls"},
#  {'type': 'corres_topic',
#   'id': 'P4BJL0LW',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'jpZRDCpS',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> action(s), human"},
#  {'type': 'corres_topic',
#   'id': 'vYqlS8Ci',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'kOJUnlSs',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> moral psychology"},
#  {'type': 'corres_topic',
#   'id': '9u6RvcAv',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'vCP1yert',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> tragedies, and happiness/sadness"},
#  {'type': 'corres_topic',
#   'id': 'GREXpxPm',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'C5dm2pHj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> health, bodily"},
#  {'type': 'corres_topic',
#   'id': 'qzct9YDU',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'dLU3wbL1',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> conscience"},
#  {'type': 'corres_topic',
#   'id': 'VQAzoMJu',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'tNHEasFJ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> mind"},
#  {'type': 'corres_topic',
#   'id': 'PY72ts1H',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'sCbRMMNW',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> sadness"},
#  {'type': 'corres_topic',
#   'id': 'B9MpbZBc',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'KaoxzxF5',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> medicine"},
#  {'type': 'corres_topic',
#   'id': 'f7XEH5W6',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': '7TSaQUdt',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> Stoic philosophy"},
#  {'type': 'corres_topic',
#   'id': 'KiUCwyFw',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'pXuh9lpt',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> duty, knowledge of"},
#  {'type': 'corres_topic',
#   'id': 'nvaLmDvU',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': 'tTXfLfwS',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'E8M3z81e',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> felicity"},
#  {'type': 'corres_topic',
#   'id': '9pD9Mvdg',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'NqoLlEyC',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> Epicurus"},
#  {'type': 'corres_topic',
#   'id': 'iE2pWbyW',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'AKJxgAxz',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> immortality of the soul"},
#  {'type': 'corres_topic',
#   'id': 'De2xtBCE',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'i7ZexkNl',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> body, human"},
#  {'type': 'corres_topic',
#   'id': 'LrKqifBP',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'ZyfH5CEi',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> attention, diversion of"},
#  {'type': 'corres_topic',
#   'id': 't8aKmKYU',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'jjjM5oY7',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'nSuwxCnD',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> contentment (of mind)"},
#  {'type': 'corres_topic',
#   'id': 'LmZxEh9m',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'BKVug8TA',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> passion"},
#  {'type': 'corres_topic',
#   'id': 'iJ9eVsMk',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'ggkrIsIP',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> friendship"},
#  {'type': 'corres_topic',
#   'id': 'lppWj9u1',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'BvHdtlwg',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> compassion"},
#  {'type': 'corres_topic',
#   'id': 'UpUyNHTd',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'VgkRNstB',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> moral philosophy"},
#  {'type': 'corres_topic',
#   'id': 'RLggdDYn',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'vmGb8ggb',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> Fortune"},
#  {'type': 'corres_topic',
#   'id': 'WZbrTgbc',
#   'source': '4b928934-ffd8-418f-9822-b9e4b562d7b0',
#   'target': 'YXrgzjuv',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/18/1645'] -> good(s)"},
#  {'type': 'corres_topic',
#   'id': 'jGUBceZD',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'hUgDETng',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> body/bodies"},
#  {'type': 'corres_topic',
#   'id': '9iefiNJ3',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'gBVqBkpb',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> sex, female"},
#  {'type': 'corres_topic',
#   'id': 'fh5iR1I9',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'w1oqbthx',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> souls"},
#  {'type': 'corres_topic',
#   'id': 'mzotzLMg',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'fFnkiNAD',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> spleen, function of"},
#  {'type': 'corres_topic',
#   'id': 'OZyplxdM',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'o7U5PDAc',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> heart, movements of"},
#  {'type': 'corres_topic',
#   'id': '0KZgM4oo',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'C5dm2pHj',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> health, bodily"},
#  {'type': 'corres_topic',
#   'id': 'ujfsype7',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'CnfQVFP6',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> spa, waters of"},
#  {'type': 'corres_topic',
#   'id': 'b0PwnihQ',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'dLU3wbL1',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> conscience"},
#  {'type': 'corres_topic',
#   'id': '0n10q0WU',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'tNHEasFJ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> mind"},
#  {'type': 'corres_topic',
#   'id': 'CYxZs0wU',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'sCbRMMNW',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> sadness"},
#  {'type': 'corres_topic',
#   'id': 'H79AfKP1',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'pwBYUODP',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> evils"},
#  {'type': 'corres_topic',
#   'id': 'K7dAk42b',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'DAvnmVDy',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> motions/movement"},
#  {'type': 'corres_topic',
#   'id': 'yPK5Qfcs',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': 'W6zZirGK',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'shAWQ5Tb',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> White, Thomas (Albanus)"},
#  {'type': 'corres_topic',
#   'id': 'kdvD7t2z',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'E8M3z81e',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> felicity"},
#  {'type': 'corres_topic',
#   'id': 'cx1M7nEW',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'i7ZexkNl',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> body, human"},
#  {'type': 'corres_topic',
#   'id': 'jcak3XXW',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'LwVEW7Uz',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': '8UHSE5RQ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> anxiety"},
#  {'type': 'corres_topic',
#   'id': 'DX81yH0P',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'JIjE7eXt',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> Bohemia, House of"},
#  {'type': 'corres_topic',
#   'id': 'AIu0Rjwc',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'BKVug8TA',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> passion"},
#  {'type': 'corres_topic',
#   'id': 'jcrKGgyj',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'ggkrIsIP',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> friendship"},
#  {'type': 'corres_topic',
#   'id': '7n1OPA0M',
#   'source': '341fd9b2-d449-4747-a8c1-eb5af4b58f98',
#   'target': 'vmGb8ggb',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/24/1645'] -> Fortune"},
#  {'type': 'corres_topic',
#   'id': 'hNJZnBpS',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'SQKezk6S',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> maxims"},
#  {'type': 'corres_topic',
#   'id': 'jL8wH7tY',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'sBF3kMIZ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> imagination"},
#  {'type': 'corres_topic',
#   'id': 'RlWZvvTw',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'fFnkiNAD',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> spleen, function of"},
#  {'type': 'corres_topic',
#   'id': 'GvNIzQ0r',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'kqcueRNl',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> expression of passions"},
#  {'type': 'corres_topic',
#   'id': 'CYsk1FXf',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'vCP1yert',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> tragedies, and happiness/sadness"},
#  {'type': 'corres_topic',
#   'id': 'llG7IA9W',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'o7U5PDAc',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> heart, movements of"},
#  {'type': 'corres_topic',
#   'id': '04O7KUXe',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'C5dm2pHj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> health, bodily"},
#  {'type': 'corres_topic',
#   'id': 'RwEsQ9LU',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'CnfQVFP6',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> spa, waters of"},
#  {'type': 'corres_topic',
#   'id': 'kjHLbKHp',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'tNHEasFJ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> mind"},
#  {'type': 'corres_topic',
#   'id': 'AOgNnrZB',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'sCbRMMNW',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> sadness"},
#  {'type': 'corres_topic',
#   'id': 'jgAbIvYw',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': '3XeY56Kf',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> enemies"},
#  {'type': 'corres_topic',
#   'id': 'k0IiosG3',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': 'i9ykqk9d',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'OFb3BlyA',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> lungs"},
#  {'type': 'corres_topic',
#   'id': 'vEKhTdg2',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'I1KdbNnZ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> prudence"},
#  {'type': 'corres_topic',
#   'id': 'psSvzWLJ',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'l7XXPhGC',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> blood"},
#  {'type': 'corres_topic',
#   'id': 'GlPTg2DZ',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'mmWWLCJf',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> understanding"},
#  {'type': 'corres_topic',
#   'id': 'eos6zGWA',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'ZyfH5CEi',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> attention, diversion of"},
#  {'type': 'corres_topic',
#   'id': 'eDA8pwmn',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'FuhZOtH3',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> sighs as signs of passions"},
#  {'type': 'corres_topic',
#   'id': '1BL35vHR',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'gy20POhh',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'nSuwxCnD',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> contentment (of mind)"},
#  {'type': 'corres_topic',
#   'id': 'JUWU3VS2',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'TPrBhVCZ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> joy"},
#  {'type': 'corres_topic',
#   'id': 'd9RBr63G',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'BKVug8TA',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> passion"},
#  {'type': 'corres_topic',
#   'id': 'GpKIt1jS',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'ggkrIsIP',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> friendship"},
#  {'type': 'corres_topic',
#   'id': '6ygbqMuX',
#   'source': '5eb81def-c454-4242-a52a-08aff7d89159',
#   'target': 'YXrgzjuv',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['05/??/1645, 06/??/1645'] -> good(s)"},
#  {'type': 'corres_topic',
#   'id': 'UxHm2Okt',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'sBF3kMIZ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/22/1645'] -> imagination"},
#  {'type': 'corres_topic',
#   'id': 'KQcT1zeb',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'gBVqBkpb',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/22/1645'] -> sex, female"},
#  {'type': 'corres_topic',
#   'id': '1oH3bmIU',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'C5dm2pHj',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/22/1645'] -> health, bodily"},
#  {'type': 'corres_topic',
#   'id': 'j2cZiYLo',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'CnfQVFP6',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/22/1645'] -> spa, waters of"},
#  {'type': 'corres_topic',
#   'id': 'pWDmBHe6',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'tNHEasFJ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/22/1645'] -> mind"},
#  {'type': 'corres_topic',
#   'id': 'UL1QKUBW',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/22/1645'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': 'Fxu31xMc',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'i7ZexkNl',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/22/1645'] -> body, human"},
#  {'type': 'corres_topic',
#   'id': 'S6zY21Gq',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'mmWWLCJf',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/22/1645'] -> understanding"},
#  {'type': 'corres_topic',
#   'id': 'PAGQ86bu',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'pnEhUqg5',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/22/1645'] -> Groningen, University of"},
#  {'type': 'corres_topic',
#   'id': 'ZIzxp6pp',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'BKVug8TA',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/22/1645'] -> passion"},
#  {'type': 'corres_topic',
#   'id': 'sdYbr5oq',
#   'source': '46cacd5a-df69-4c8c-bb71-5f75ba7f76d5',
#   'target': 'ggkrIsIP',
#   'value': 1,
# ...
#   'source': '90315087-93fd-48e6-8ee0-5a67b583e7ed',
#   'target': 'PDxvN46F',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['05/??/1647'] -> nature, phenomena of"},
#  {'type': 'corres_topic',
#   'id': '0XBqGJ7X',
#   'source': '2845332c-87fb-4eac-98e2-568fe1511b37',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/06/1647'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'aSMAnB5N',
#   'source': '2845332c-87fb-4eac-98e2-568fe1511b37',
#   'target': 'nSuwxCnD',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/06/1647'] -> contentment (of mind)"},
#  {'type': 'corres_topic',
#   'id': 'PDQyyXiO',
#   'source': 'db61ff11-d3e8-477b-933f-929fee1fb643',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['11/20/1647'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'XRvURbZT',
#   'source': 'db61ff11-d3e8-477b-933f-929fee1fb643',
#   'target': 'jCJ0VuxN',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['11/20/1647'] -> sovereign good"},
#  {'type': 'corres_topic',
#   'id': 'wGIo8fCy',
#   'source': '7c760700-b37e-498d-be50-d9cc74d376ee',
#   'target': 'ggkrIsIP',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['12/05/1647'] -> friendship"},
#  {'type': 'corres_topic',
#   'id': 'S4Hw5xdp',
#   'source': '60014d01-a7fc-42d0-8072-e9e2a1ad0053',
#   'target': 'i7ZexkNl',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['01/31/1648'] -> body, human"},
#  {'type': 'corres_topic',
#   'id': 'JAYKaAig',
#   'source': '60014d01-a7fc-42d0-8072-e9e2a1ad0053',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['01/31/1648'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'uzJhomzQ',
#   'source': '60014d01-a7fc-42d0-8072-e9e2a1ad0053',
#   'target': 'x6tVoAG9',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['01/31/1648'] -> animals"},
#  {'type': 'corres_topic',
#   'id': 'bCI7Vj9X',
#   'source': '60014d01-a7fc-42d0-8072-e9e2a1ad0053',
#   'target': 'XDoEmZcf',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['01/31/1648'] -> scholastic philosophy/philosophers"},
#  {'type': 'corres_topic',
#   'id': 'qS1Pn7qu',
#   'source': '60014d01-a7fc-42d0-8072-e9e2a1ad0053',
#   'target': 'jCJ0VuxN',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['01/31/1648'] -> sovereign good"},
#  {'type': 'corres_topic',
#   'id': 'lwVfke2N',
#   'source': 'e9495a6b-6d6a-4634-80c8-d8f44942c4ed',
#   'target': '1OsHMwXM',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/30/1648'] -> bleeding as remedy"},
#  {'type': 'corres_topic',
#   'id': 'ej02rhbB',
#   'source': 'e9495a6b-6d6a-4634-80c8-d8f44942c4ed',
#   'target': 'q3bteYXb',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/30/1648'] -> English Civil War"},
#  {'type': 'corres_topic',
#   'id': 'xmh8wd5f',
#   'source': 'e9495a6b-6d6a-4634-80c8-d8f44942c4ed',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/30/1648'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': 'YS2a2md9',
#   'source': 'e9495a6b-6d6a-4634-80c8-d8f44942c4ed',
#   'target': 'eeUsdwD6',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['06/30/1648'] -> Westphalia, Peace of (Treaties of Munster)"},
#  {'type': 'corres_topic',
#   'id': '8nloU6Z4',
#   'source': '40643f9f-c7be-405a-87fb-2c4c11d84b5b',
#   'target': 'I1KdbNnZ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/??/1648, 07/??/1648'] -> prudence"},
#  {'type': 'corres_topic',
#   'id': 'sUOeWcYB',
#   'source': '40643f9f-c7be-405a-87fb-2c4c11d84b5b',
#   'target': 'VwsFgDtH',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/??/1648, 07/??/1648'] -> parlement (French)"},
#  {'type': 'corres_topic',
#   'id': 'HK3IYHII',
#   'source': '40643f9f-c7be-405a-87fb-2c4c11d84b5b',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/??/1648, 07/??/1648'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': '0fnTbKkW',
#   'source': '40643f9f-c7be-405a-87fb-2c4c11d84b5b',
#   'target': 'nSuwxCnD',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/??/1648, 07/??/1648'] -> contentment (of mind)"},
#  {'type': 'corres_topic',
#   'id': 'qspscIM0',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': '64BwZVKf',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> pleasures"},
#  {'type': 'corres_topic',
#   'id': 'ouPcTHyv',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': 'C5dm2pHj',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> health, bodily"},
#  {'type': 'corres_topic',
#   'id': 'ECMvuXjh',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': 'dLU3wbL1',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> conscience"},
#  {'type': 'corres_topic',
#   'id': 'bo27HNrJ',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': 'MvE4w1C7',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> freedom"},
#  {'type': 'corres_topic',
#   'id': 'CXcrYGdd',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': 'nbTGTdv8',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': 'I1KdbNnZ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> prudence"},
#  {'type': 'corres_topic',
#   'id': 'wTgjCXnw',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': 'ZyfH5CEi',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> attention, diversion of"},
#  {'type': 'corres_topic',
#   'id': 'K6YZ4UPZ',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'HI977vCI',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': 'JIjE7eXt',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> Bohemia, House of"},
#  {'type': 'corres_topic',
#   'id': 'OBDwHYAZ',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': 'uVYJyHi0',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> liberty"},
#  {'type': 'corres_topic',
#   'id': 'nKPIf3yA',
#   'source': 'd3af4c31-8c6a-4bc9-be55-c280412e3f4a',
#   'target': 'vmGb8ggb',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['07/??/1648'] -> Fortune"},
#  {'type': 'corres_topic',
#   'id': '5e9mth27',
#   'source': 'f8d0887b-f46c-4233-841c-0ef9fb1a5a4c',
#   'target': '1OsHMwXM',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/23/1648'] -> bleeding as remedy"},
#  {'type': 'corres_topic',
#   'id': 'Bs1ARHlw',
#   'source': 'f8d0887b-f46c-4233-841c-0ef9fb1a5a4c',
#   'target': 'C5dm2pHj',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/23/1648'] -> health, bodily"},
#  {'type': 'corres_topic',
#   'id': 'Rhv2yJaB',
#   'source': 'f8d0887b-f46c-4233-841c-0ef9fb1a5a4c',
#   'target': 'tNHEasFJ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/23/1648'] -> mind"},
#  {'type': 'corres_topic',
#   'id': 'cSrOM8Ri',
#   'source': 'f8d0887b-f46c-4233-841c-0ef9fb1a5a4c',
#   'target': 'q3bteYXb',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/23/1648'] -> English Civil War"},
#  {'type': 'corres_topic',
#   'id': 'a4V7aSqN',
#   'source': 'f8d0887b-f46c-4233-841c-0ef9fb1a5a4c',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/23/1648'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': '39z8FqRF',
#   'source': 'f8d0887b-f46c-4233-841c-0ef9fb1a5a4c',
#   'target': 'A6NSvcFs',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/23/1648'] -> superstition"},
#  {'type': 'corres_topic',
#   'id': 'Rb4FN0ES',
#   'source': 'f8d0887b-f46c-4233-841c-0ef9fb1a5a4c',
#   'target': 'FfT2d8LJ',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/23/1648'] -> Christina (queen of Sweden)"},
#  {'type': 'corres_topic',
#   'id': '7nYozOZZ',
#   'source': 'f8d0887b-f46c-4233-841c-0ef9fb1a5a4c',
#   'target': 'jHDbP07B',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/23/1648'] -> Chanut, Hector-Pierre"},
#  {'type': 'corres_topic',
#   'id': 'Hkc0z4rN',
#   'source': 'f8d0887b-f46c-4233-841c-0ef9fb1a5a4c',
#   'target': 'YXrgzjuv',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/23/1648'] -> good(s)"},
#  {'type': 'corres_topic',
#   'id': 'YRFztEj6',
#   'source': 'f8d0887b-f46c-4233-841c-0ef9fb1a5a4c',
#   'target': 'PDxvN46F',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['08/23/1648'] -> nature, phenomena of"},
#  {'type': 'corres_topic',
#   'id': 'dd3KF7Db',
#   'source': '4b0b5a94-0520-4fb2-a100-01fae176b988',
#   'target': 'C5dm2pHj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['10/??/1648'] -> health, bodily"},
#  {'type': 'corres_topic',
#   'id': 'gNLFhO2X',
#   'source': '4b0b5a94-0520-4fb2-a100-01fae176b988',
#   'target': 'E8M3z81e',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['10/??/1648'] -> felicity"},
#  {'type': 'corres_topic',
#   'id': '9Ejx4pop',
#   'source': '4b0b5a94-0520-4fb2-a100-01fae176b988',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['10/??/1648'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': '55kspqx7',
#   'source': '4b0b5a94-0520-4fb2-a100-01fae176b988',
#   'target': 'UIiP03iw',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['10/??/1648'] -> analogy/analogies"},
#  {'type': 'corres_topic',
#   'id': 'nmqoaaoY',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'sBF3kMIZ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> imagination"},
#  {'type': 'corres_topic',
#   'id': '3RUHL4HT',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'BNUFPxT8',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> pain"},
#  {'type': 'corres_topic',
#   'id': '4zd5Qe7O',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'J8OrruZE',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> glory"},
#  {'type': 'corres_topic',
#   'id': '0aNy42F4',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'w1oqbthx',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> souls"},
#  {'type': 'corres_topic',
#   'id': 'id5lqaSS',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'a4cPwfNp',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> indignation"},
#  {'type': 'corres_topic',
#   'id': 'EPrG0Ufa',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'jOVOr0sW',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> Palatinate"},
#  {'type': 'corres_topic',
#   'id': '1zsZJ1sD',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'dLU3wbL1',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> conscience"},
#  {'type': 'corres_topic',
#   'id': 'sFjoyQ7l',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'sCbRMMNW',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> sadness"},
#  {'type': 'corres_topic',
#   'id': 'WRbq3JBL',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'q3bteYXb',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> English Civil War"},
#  {'type': 'corres_topic',
#   'id': 'XsY1acv1',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'lsakkT6F',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> war"},
#  {'type': 'corres_topic',
#   'id': 'HYAJgkH6',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'BhRjF2Z2',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> spirits, animal"},
#  {'type': 'corres_topic',
#   'id': 'wtMgismS',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'NEEXGCGI',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> Elisabeth, Princess of Bohemia"},
#  {'type': 'corres_topic',
#   'id': '58acoBCL',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'eeUsdwD6',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> Westphalia, Peace of (Treaties of Munster)"},
#  {'type': 'corres_topic',
#   'id': 'O2Sai3qP',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'I1KdbNnZ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> prudence"},
#  {'type': 'corres_topic',
#   'id': 'aK2k4Qa8',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'iHMKRku0',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> brain"},
#  {'type': 'corres_topic',
#   'id': 'u7oNyHTn',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'vmGb8ggb',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> Fortune"},
#  {'type': 'corres_topic',
#   'id': 'DL4D5U9g',
#   'source': '8a4990c2-da48-4e4d-8568-da12f9ba3161',
#   'target': 'OqcyZ10a',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['02/22/1649'] -> animal spirits"},
#  {'type': 'corres_topic',
#   'id': 'qUaS5LoY',
#   'source': '93b71464-d406-418b-af04-a4ff70839f2f',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['03/31/1649'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'smo9c6cJ',
#   'source': '93b71464-d406-418b-af04-a4ff70839f2f',
#   'target': 'jCJ0VuxN',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['03/31/1649'] -> sovereign good"},
#  {'type': 'corres_topic',
#   'id': 'dcAddSYo',
#   'source': '70fe97f6-b928-4ab9-b568-5d6499ceda02',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['06/??/1649'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'sfr60LDB',
#   'source': '04039852-d2c9-455a-92af-acb02d88830a',
#   'target': 'CBSCyXti',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['10/09/1649'] -> philosophy and philosophers"},
#  {'type': 'corres_topic',
#   'id': 'WU6AYfnB',
#   'source': '04039852-d2c9-455a-92af-acb02d88830a',
#   'target': 'tNHEasFJ',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['10/09/1649'] -> mind"},
#  {'type': 'corres_topic',
#   'id': 'ixrxYgQz',
#   'source': '04039852-d2c9-455a-92af-acb02d88830a',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['10/09/1649'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': 'YbHoSZyl',
#   'source': '04039852-d2c9-455a-92af-acb02d88830a',
#   'target': 'yx8AgNeL',
#   'value': 1,
#   'name': "Descartes, René TO Princess Elisabeth ['10/09/1649'] -> jealousy"},
#  {'type': 'corres_topic',
#   'id': 'VvdO1Nus',
#   'source': 'b131a17d-0013-4474-bffa-d52556869a30',
#   'target': 'gBVqBkpb',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['12/04/1649'] -> sex, female"},
#  {'type': 'corres_topic',
#   'id': '5aJB5xpP',
#   'source': 'b131a17d-0013-4474-bffa-d52556869a30',
#   'target': 'mfw8NFqy',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['12/04/1649'] -> Jesuits (Society of Jesus)"},
#  {'type': 'corres_topic',
#   'id': 'x9aQOKZ8',
#   'source': 'b131a17d-0013-4474-bffa-d52556869a30',
#   'target': 'oN6PdpGj',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['12/04/1649'] -> Descartes, René"},
#  {'type': 'corres_topic',
#   'id': '5nVPYjrM',
#   'source': 'b131a17d-0013-4474-bffa-d52556869a30',
#   'target': 'yx8AgNeL',
#   'value': 1,
#   'name': "Princess Elisabeth TO Descartes, René ['12/04/1649'] -> jealousy"}]

# %% [markdown]
# {
#     "labels": ["Faculty"],
#     "id": 6,
#     "properties": {
#     "x": "xx",
#     "xxx": [],
#     }
# },
#
#
# {
#     "type": "has_interest",
#     "properties": {},
#     "id": 147,
#     "source": 21,
#     "target": 344,
#     "value": 1
# },
